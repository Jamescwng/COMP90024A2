# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
suburbData = pd.read_pickle("./suburbData.pkl")
suburbData
# Out:
#                                                                geometry  \
# LOC_NAME
# Melbourne             POLYGON ((144.97797 -37.83867, 144.97803 -37.8...
# Southbank             POLYGON ((144.95308 -37.82740, 144.95328 -37.8...
# St Kilda              POLYGON ((144.99038 -37.87073, 144.99036 -37.8...
# Docklands             POLYGON ((144.95376 -37.82363, 144.95336 -37.8...
# Richmond              POLYGON ((145.00407 -37.83137, 145.00396 -37.8...
# ...                                                                 ...
# Sandringham           POLYGON ((145.00670 -37.95693, 145.00655 -37.9...
# Upper Ferntree Gully  POLYGON ((145.32416 -37.89994, 145.32414 -37.9...
# Yarra Glen            POLYGON ((145.36232 -37.67205, 145.36236 -37.6...
# Rosanna               POLYGON ((145.08284 -37.74245, 145.08300 -37.7...
# Burnside Heights      POLYGON ((144.76353 -37.72942, 144.76349 -37.7...
#
#                       counts   %                suburb
# LOC_NAME
# Melbourne               7500  79             Melbourne
# Southbank               1543  83             Southbank
# St Kilda                1457  69              St Kilda
# Docklands               1070  76             Docklands
# Richmond                1008  74              Richmond
# ...                      ...  ..                   ...
# Sandringham               51  88           Sandringham
# Upper Ferntree Gully      51  50  Upper Ferntree Gully
# Yarra Glen                51  84            Yarra Glen
# Rosanna                   51  58               Rosanna
# Burnside Heights          50  72      Burnside Heights
#
# [253 rows x 4 columns]

# %%
pollutantData = pd.read_pickle("./pollutantData.pkl")
pollutantData
# Out:
#                                                                geometry  \
# LOC_NAME
# Melbourne             POLYGON ((144.97797 -37.83867, 144.97803 -37.8...
# Southbank             POLYGON ((144.95308 -37.82740, 144.95328 -37.8...
# St Kilda              POLYGON ((144.99038 -37.87073, 144.99036 -37.8...
# Docklands             POLYGON ((144.95376 -37.82363, 144.95336 -37.8...
# Richmond              POLYGON ((145.00407 -37.83137, 145.00396 -37.8...
# ...                                                                 ...
# Sandringham           POLYGON ((145.00670 -37.95693, 145.00655 -37.9...
# Upper Ferntree Gully  POLYGON ((145.32416 -37.89994, 145.32414 -37.9...
# Yarra Glen            POLYGON ((145.36232 -37.67205, 145.36236 -37.6...
# Rosanna               POLYGON ((145.08284 -37.74245, 145.08300 -37.7...
# Burnside Heights      POLYGON ((144.76353 -37.72942, 144.76349 -37.7...
#
#                       counts                suburb
# LOC_NAME
# Melbourne               24.0             Melbourne
# Southbank                4.0             Southbank
# St Kilda                 0.0              St Kilda
# Docklands               19.0             Docklands
# Richmond                26.0              Richmond
# ...                      ...                   ...
# Sandringham              1.0           Sandringham
# Upper Ferntree Gully    13.0  Upper Ferntree Gully
# Yarra Glen              15.0            Yarra Glen
# Rosanna                  0.0               Rosanna
# Burnside Heights         0.0      Burnside Heights
#
# [253 rows x 3 columns]

# %%
correlationData = pd.merge(suburbData, pollutantData, left_index=True, right_index=True)

# %%
correlationData[['%','counts_y']]
# Out:
#                        %  counts_y
# LOC_NAME
# Melbourne             79      24.0
# Southbank             83       4.0
# St Kilda              69       0.0
# Docklands             76      19.0
# Richmond              74      26.0
# ...                   ..       ...
# Sandringham           88       1.0
# Upper Ferntree Gully  50      13.0
# Yarra Glen            84      15.0
# Rosanna               58       0.0
# Burnside Heights      72       0.0
#
# [253 rows x 2 columns]

# %%
# a scatter plot comparing % positive tweets and reports of pollutants
df.plot(kind='scatter',x='num_children',y='num_pets',color='red')
plt.show()
